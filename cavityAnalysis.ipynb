# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.signal import find_peaks
from matplotlib.collections import LineCollection
import sys
import os

plt.rcParams["text.usetex"] = True
plt.rcParams["font.size"] = 12


# Read the CSV file
df = pd.read_csv("etaNvz.csv")

# Create the figure and axis
fig, ax1 = plt.subplots(figsize=(145/25.4, 100/25.4))
# Plot the data
ax1.plot(df["t"], df["vz"], '-')
ax1.plot(df["t"], df["vz"], '.')
ax1.set_xlabel(r"$t$")
ax1.set_ylabel(r"$v_z$")
# ax1.set_ylim(-1, 2)
# ax1.set_xlim(0, 1.0)

# Show the plot
plt.show()
